# %% [markdown]
# ##                                                                       INT 353
# ### Name- Gautam kumar
# ### Reg.no- 12019286
# ### Section- K20MD
# ### Roll no – RK20MDA36
# ### My Dataset- Data mobile price range

# %% [markdown]
# ## why this project?
#
# ### Mobile phones have changed our communication habits in the first decade of the twenty-first century.In a few years, the world coverage of mobile phone subscriptions has raised from 12% of the world  population in 2000 up to 96% in 2014 - 6.8 billion subscriber. The  main objective of this project is to predict the price range of mobile phone. By which future technology and demand price can be predicted. The price ranges from 0-3. I’ll discuss the price range in the dataset.

# %% [markdown]
# ## which Domain it belongs to?
#
# ### It belongs to business domain.

# %% [markdown]
# ## Information on Dataset.

# %% [markdown]
# ### This dataset contains, On the basis of the mobile Specification like Battery power, 3G enabled , wifi ,Bluetooth, Ram ,Battery power, clock speed, px_height, px_width, Camera . This dataset contains 2000 rows 21 columns. These are the following columns in dataset
#
# ### battery_power:Total energy a battery can store in one time measured in mAh
# ### blue:Has bluetooth or not
# ### clock_speed:speed at which microprocessor executes instructions
# ### dual_sim:Has dual sim support or not
# ### fc:Front Camera mega pixels
# ### m_dep:Mobile Depth in cm
# ### mobile_wt:Weight of mobile phone
# ### n_cores:Number of cores of processor
# ### pc:Primary Camera mega pixels
# ### px_height:Pixel Resolution Height
# ### px_width:Pixel Resolution Width
# ### sc_h:Screen Height of mobile in cm
# ### sc_w:Screen Width of mobile in cm
# ### talk_time:longest time that a single battery charge will last when you are
# ### three_g:Has 3G or not
# ### touch_screen:Has touch screen or not

# %% [markdown]
# ## What is your approach?

# %% [markdown]
# ### My approach is ,first of all import all required libraries like pandas, matplotlib, etc. These libraries are used to load, preprocess and visualize the dataset. Cleaning the dataset by replacing values, repeated values or by removing null values. Analysing the dataset on the basis of different relation in between, i plot some graphs like barplot, histogram, scatter plot, distribution plot etc. And after plotting all graphs gives some conclusions ,what are the specifications etc.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data_mobile_price_range.csv")
df.shape
# Out:
# (2000, 21)

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.dropna()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
plt.figure(figsize =(12,6))
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# # plotting relation betweem price range and battery power

# %%
plt.figure(figsize =(16,8))
sns.barplot(x = 'price_range', y = 'battery_power', data=df)
plt.show()

# %% [markdown]
# # Plotting Relation between Price Range and Pixel Height/width

# %%
plt.figure(figsize =(16,7))
plt.subplot(1,2,1)
sns.barplot(x='price_range',y='px_height', data=df, palette='Blues')
plt.subplot(1,2,2)
sns.barplot(x='price_range', y='px_width', data=df, palette='Reds')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Plotting Relation between Range and Ram

# %%
plt.figure(figsize =(12,6))
sns.barplot(x ='price_range', y='ram', data=df)
plt.show()

# %% [markdown]
# # Plotting  Relation between Price Range and 3G/4G Network

# %%
plt.figure(figsize =(12,6))
sns.countplot(df['three_g'], hue =df['price_range'], palette='pink')
plt.show()
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(12,6))
sns.countplot(df['four_g'], hue =df['price_range'], palette='ocean')
plt.show()
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Plotting Relation between Clock speed and Wifi

# %%
plt.figure(figsize =(16,8))
sns.barplot(x = 'clock_speed', y = 'wifi', data=df)
plt.show()

# %% [markdown]
# # Plotting Relation between Price Range and Dual sim

# %%
plt.figure(figsize =(12,6))
sns.countplot(df['dual_sim'], hue =df['price_range'], palette='ocean')
plt.show()
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# ## categorical and numerical columns

# %%
 cat=[]
num=[]
for column in df.columns:
        if df[column].nunique()>5:
            num.append(column)
        else:
            cat.append(column)

# %%
cat
# Out:
# ['blue',
#  'dual_sim',
#  'four_g',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
num
# Out:
# ['battery_power',
#  'clock_speed',
#  'fc',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time']

# %% [markdown]
# # Univariate Analysis
# # countplot

# %%
df['dual_sim'].value_counts()
# Out:
# 1    1019
# 0     981
# Name: dual_sim, dtype: int64

# %%
sns.countplot(df['dual_sim'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='dual_sim', ylabel='count'>

# %% [markdown]
# ###  Number of mobile phones having dual sim have a slightly higher as compared to non dual sim.

# %%
sns.countplot(df['four_g'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='four_g', ylabel='count'>

# %%
sns.countplot(df['talk_time'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='talk_time', ylabel='count'>

# %%
df['four_g'].value_counts().plot(kind="pie",autopct="%1.5f")
# Out:
# <AxesSubplot:ylabel='four_g'>

# %%
df['blue'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Here we can see that  No of bluetooth containing mobile phones are almost equal to mobile that are not having bluetooth

# %%
df['blue'].value_counts().plot(kind="pie",autopct="%1.5f")
# Out:
# <AxesSubplot:ylabel='blue'>

# %% [markdown]
# ### No of bluetooth containing mobile phones are slightly less than mobile that are not having bluetooth.

# %%
df['four_g'].value_counts()
# Out:
# 1    1043
# 0     957
# Name: four_g, dtype: int64

# %%
df['four_g'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### From this barplot we can conclude that no of mobile phones having four_g network is more than 1000.

# %%
df['three_g'].value_counts()
# Out:
# 1    1523
# 0     477
# Name: three_g, dtype: int64

# %%
df['three_g'].value_counts().plot(kind="pie",autopct="%1.5f")
# Out:
# <AxesSubplot:ylabel='three_g'>

# %% [markdown]
#  ### From this plot we can see that the number of 3g phones are more than 75%.

# %%
df['dual_sim'].value_counts().plot(kind="pie",autopct="%1.5f")
# Out:
# <AxesSubplot:ylabel='dual_sim'>

# %%
sns.stripplot(x=df["dual_sim"])
# Out:
# <AxesSubplot:xlabel='dual_sim'>

# %%
sns.violinplot(x=df["wifi"])
# Out:
# <AxesSubplot:xlabel='wifi'>

# %%
df['blue'].value_counts()
# Out:
# 0    1010
# 1     990
# Name: blue, dtype: int64

# %%
df['wifi'].value_counts()
# Out:
# 1    1014
# 0     986
# Name: wifi, dtype: int64

# %%
sns.boxplot(data=df.loc[:, ['wifi', 'blue']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### From here we can observe that number of mobile phones having wifi and no of mobile phones having bluetooth are almost equal.

# %%
sns.boxplot(x=df['price_range'])
# Out:
# <AxesSubplot:xlabel='price_range'>

# %%
sns.kdeplot(x='three_g', data=df, hue='blue')
# Out:
# <AxesSubplot:xlabel='three_g', ylabel='Density'>

# %%
num
# Out:
# ['battery_power',
#  'clock_speed',
#  'fc',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time']

# %%
sns.distplot(df['battery_power'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='battery_power', ylabel='Density'>

# %% [markdown]
# ### here we can see that at starting density  is  increases with battery_power but after sometime density became constant and start decreasing rapidly with increase of battery_power.

# %%
df['battery_power'].skew()
# Out:
# 0.03189847179278164

# %% [markdown]
# ### skewness of battery power is not so much it is less than 1.

# %%
sns.distplot(df['clock_speed'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='clock_speed', ylabel='Density'>

# %%
df['clock_speed'].skew()
# Out:
# 0.1780841202790887

# %% [markdown]
# ### output value is positive so we can analyse it is right skewed.

# %%
sns.boxplot(df['int_memory'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='int_memory'>

# %% [markdown]
# # Bivariate Analysis

# %%
cat
# Out:
# ['blue',
#  'dual_sim',
#  'four_g',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %% [markdown]
# ### blue , dual_sim , four_g, three_g , touch_screen, wifi , price_range  these are the categorical columns in dataset.

# %%
num
# Out:
# ['battery_power',
#  'clock_speed',
#  'fc',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time']

# %% [markdown]
# ### ['battery_power','Clock_speed' ,fc , int_memory , m_deep, mobile_wt, n_cores, pc , px_height, px_width , ram , sc_h, sc_w , talk_time are nuemrical columns in dataset].

# %%
sns.boxplot(x="price_range", y="battery_power", data=df)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='battery_power'>

# %% [markdown]
# ### Here we can see that with the increment in the price of mobile phones , battery_power also increases. Maximum mobile price having maximum battery_power.

# %%
sns.boxplot(x="price_range", y="touch_screen", data=df)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='touch_screen'>

# %%
sns.barplot(df['price_range'],df['px_height'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='px_height'>

# %%
sns.histplot(x='price_range', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='Count'>

# %%
sns.pointplot(y="talk_time", x="price_range", data=df)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='talk_time'>

# %% [markdown]
# ###  Mobile phones  having  talk_time that a single battery charge will last

# %%
sns.scatterplot(df['battery_power'],df['px_height'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='battery_power', ylabel='px_height'>

# %%
sns.scatterplot(df['talk_time'],df['pc'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='talk_time', ylabel='pc'>

# %%
sns.barplot(df['three_g'],df['talk_time'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='three_g', ylabel='talk_time'>

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
plt.figure(figsize = (12, 6))

sns.countplot(df['dual_sim'], hue = df['price_range'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='dual_sim', ylabel='count'>

# %% [markdown]
# ###  Here we can see that ,there is no major difference in term of number of phones that has dual sim in every price range.

# %% [markdown]
# ## Multivariate analysis

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(df['ram'], df['battery_power'], hue = df['price_range'], palette ='dark')
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ram', ylabel='battery_power'>

# %% [markdown]
# ### from the scatter plot we can see that battery power vary for each ram sizes.

# %%
plt.figure(figsize = (15, 8))
sns.lineplot(df['price_range'], df['fc'])
# Out:
# C:\Users\Gautam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='fc'>

# %% [markdown]
# ### by looking at this graph the price range increase as the front camera increase
# ### however after some point the average front camera megapixel drop when the price range goes from 2 to 3
